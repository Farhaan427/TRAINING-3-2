# %% [markdown]
# # LAB TASKS ON SOFTMAX
# Name:
# Roll No:
# Date:

# %% [markdown]
# ## Task 7: Softmax vs Sigmoid

# %%
import numpy as np
logits=np.array([2.0,1.0,0.1])
sigmoid=1/(1+np.exp(-logits))
softmax=np.exp(logits)/np.sum(np.exp(logits))
sigmoid,softmax
# Out:
# (array([0.88079708, 0.73105858, 0.52497919]),
#  array([0.65900114, 0.24243297, 0.09856589]))

# %% [markdown]
# ## Task 8: Softmax + Cross Entropy

# %%
labels=0
loss=-np.log(softmax[labels])
loss
# Out:
# 0.4170300162778335

# %% [markdown]
# ## Task 9: Visualizing Softmax

# %%
import matplotlib.pyplot as plt
logits=np.random.randn(5)
softmax=np.exp(logits)/np.sum(np.exp(logits))
plt.bar(range(len(softmax)),softmax)
plt.show()

# %% [markdown]
# ## Task 10: Mini Project

# %%
vocab=['I','like','machine','translation']
logits=np.array([2.0,1.5,0.5,0.2])
softmax=np.exp(logits)/np.sum(np.exp(logits))
list(zip(vocab,softmax))
# Out:
# [('I', 0.5012632565702778),
#  ('like', 0.3040315336972736),
#  ('machine', 0.11184695071504956),
#  ('translation', 0.08285825901739881)]
